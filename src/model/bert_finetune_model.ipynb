# %%
##HYPERPARAMETERS
max_allowed_unknowns = 100 #use a multiple of 5 here please
batch_size = 32 #Unchanged
learning_rate = 2e-5 #Unchanged
warmup_steps = 0
epochs = 5 #Overfitting after 5 (ish)
num_genres = 12 #Up to 14
limit_rb_disco = True
limit_number = 600

# %%
# please make sure that the libraries in the requirements.txt are the specified versions

# %%
from transformers import BertTokenizer, BertForSequenceClassification, BertConfig, get_linear_schedule_with_warmup
import numpy as np
import torch
from torch.optim import AdamW
from torch.utils.data import TensorDataset, random_split,  DataLoader, RandomSampler, SequentialSampler
import time
import datetime
import random
import pandas as pd
import tensorflow as tf
import re
import os
from sklearn.metrics import f1_score, precision_score, confusion_matrix
import ssl
import nltk
from nltk.corpus import words
import string
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Check if there's a GPU Available
if torch.cuda.is_available():

    # Tell PyTorch to use the GPU.
    device = torch.device("cuda")

    print('There are %d GPU(s) available.' % torch.cuda.device_count())

    print('We will use the GPU:', torch.cuda.get_device_name(0))

# If not, use CPU (NOT RECOMMENDED)
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: Tesla T4

# %%
##Generate Data for Training/Validation

row_idx = int(max_allowed_unknowns / 5) #This times 5 is the top number of non-english lyrics per song for the model going forward

## from https://stackoverflow.com/questions/38916452/nltk-download-ssl-certificate-verify-failed
try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download('words')
dataset_length = []
english_vocab = set(words.words())
id_pattern = re.compile(r'^[a-zA-Z0-9]{22},')

## Used to generate data for data stacking charts
max_foreign: int = 50 #times 5

## Used to collect genre distribution data as max unknowns is increased
data_rows = []
all_possible_genres = set()  # Keep track of all genres across iterations

for current_max in range(max_foreign+1):
  ##Each loop populates all_songs and all_genres with non-empty songs from datasets (not test or test2) which have a maximum amount of non-english words
  current_song_lyrics = []
  first_id = False
  first_line = True

  english_check = True
  non_english_count = 0

  all_songs = []
  all_genres = []

  folder_path = '/content/CSCI3832_FinalProject/data'

  for filename in os.listdir(folder_path): #Copy songs and genres from dataset files
      file_path = os.path.join(folder_path, filename)
      genre_file_name = os.path.splitext(filename)[0]
      genre = genre_file_name.split('_')[0]
      if genre != "my" and genre != "test" and genre != "test2":
          with open(file_path, 'r', encoding='utf-8') as file:
              for line in file:
                  if first_line == True:
                      first_line = False
                      continue
                  else:
                      if id_pattern.match(line):
                          if first_id == False:
                              first_id = True
                          else:
                              if english_check == True and len(current_song_lyrics) > 0:
                                  lyrics_in_song = ''.join(current_song_lyrics).strip()
                                  all_songs.append(lyrics_in_song)
                                  all_genres.append(genre)
                                  #print(lyrics_in_song)
                              current_song_lyrics = []
                              english_check = True
                              non_english_count = 0
                      else:
                          no_punct = line.translate(str.maketrans('', '', string.punctuation))
                          line_words = no_punct.split()
                          for word in line_words:
                              if word.lower() not in english_vocab:
                                  non_english_count += 1
                                  if non_english_count >= current_max*5:
                                      english_check = False
                          current_song_lyrics.append(line)

              if current_song_lyrics:
                  if english_check == True and len(current_song_lyrics) > 0:
                      lyrics_in_song = ''.join(current_song_lyrics).strip()
                      all_songs.append(lyrics_in_song)
                      all_genres.append(genre)
  if current_max == row_idx: #Which iteration to keep
    all_songs_100unk = all_songs
    all_genres_100unk = all_genres
  #Add Basic Data to Row
  counter = Counter(all_genres)
  row = {
      'Max Unknown Words': current_max * 5,
      'Dataset Length': len(all_songs)
  }

  # Add genre counts to the row
  for genre, count in counter.items():
      row[genre] = count
      all_possible_genres.add(genre)

  # Append this row
  data_rows.append(row)


# After the loop ends, create the DataFrame
df = pd.DataFrame(data_rows)

# Fill missing genre columns with 0
df = df.fillna(0).astype({genre: int for genre in all_possible_genres})

##Create Dataframe that shows genre breakdown

    # Define static and genre columns
static_cols = ['Max Unknown Words', 'Dataset Length']
genre_cols = [col for col in df.columns if col not in static_cols]

    # Get the values at the specified row and sort genres
row = df.loc[row_idx, genre_cols]
top_10_genres = row.sort_values(ascending=False).head(10).index.tolist()

    # Full DataFrame sorted by that row's genre values
genre_cols_sorted = row.sort_values(ascending=False).index.tolist()
sorted_df = df[static_cols + genre_cols_sorted]

    # Top-10 DataFrame
df_top10 = df[static_cols + top_10_genres]

    # Save to files
save_directory = '/content/CSCI3832_FinalProject/SupplementaryMaterials/'
sorted_df.to_csv(f'{save_directory}bert_data_sorted_full_version.csv', index=False)
df_top10.to_csv(f'{save_directory}bert_data_top10_version.csv', index=False)
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
##These arrays keep the lyrics and labels for each song in the dataset
song_lyrics = np.array(all_songs_100unk)
song_labels = np.array(all_genres_100unk)

##FOR USING THE TOP 10 GENRES INSTEAD
# Get the top 10 labels
label_counts = Counter(song_labels)
top_n_labels = set([label for label, _ in label_counts.most_common(num_genres)])

# Create a boolean mask where label is in top 10
mask = np.isin(song_labels, list(top_n_labels))

# Apply mask
song_lyrics = song_lyrics[mask]
song_labels = song_labels[mask]
num_genres_check = len(np.unique(song_labels))

##SANITY CHECK, this variable also determines the number of output layers
print(num_genres, num_genres_check)
# Out:
# 10 10

# %%
num_rb = 0
num_disco = 0

song_lyrics_limited = []
song_labels_limited = []

for i in range(len(song_labels)):
  if song_labels[i] == "rb":
    num_rb += 1
    if num_rb < limit_number:
      song_lyrics_limited.append(song_lyrics[i])
      song_labels_limited.append(song_labels[i])
  elif song_labels[i] == "disco":
    num_disco += 1
    if num_disco < limit_number:
      song_lyrics_limited.append(song_lyrics[i])
      song_labels_limited.append(song_labels[i])
  else:
    song_lyrics_limited.append(song_lyrics[i])
    song_labels_limited.append(song_labels[i])

print(num_rb, num_disco)

if limit_rb_disco == True:
  song_lyrics = np.array(song_lyrics_limited)
  song_labels = np.array(song_labels_limited)

print(len(song_lyrics))


plt.figure(figsize=(10, 6))
sns.histplot(song_labels, kde=False)
plt.title('Distribution of Genres in Dataset')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

base_dir = '/content/CSCI3832_FinalProject/SupplementaryMaterials/'
# Create folder name with today's date
today_str = datetime.date.today().strftime('%Y-%m-%d')
subfolder_name = f"{today_str}_training"
save_directory = os.path.join(base_dir, subfolder_name)

# Create the directory if it doesn't exist
os.makedirs(save_directory, exist_ok=True)

# Save the plot as a JPG image to the specified path
plt.savefig(os.path.join(save_directory, 'genre_distribution.jpg'))

plt.show()
# Out:
# 1561 1243
# 4996

# %%
#setup tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)
##ENCODING Lyrics
encoded = tokenizer.batch_encode_plus(
    song_lyrics,
    add_special_tokens=True,      # Adds start and end tokens (for BERT)
    max_length=512,               # Limited to Max Length of 512 tokens (sad)
    padding='max_length',          # ensures all are the same lengh
    truncation=True,              # Truncate to 512 if above
    return_attention_mask=True,
    return_tensors='pt'
)

input_ids = encoded['input_ids']              # shape: (num_songs, max_len)
attention_masks = encoded['attention_mask']

##Create label encoding and decoding
unique_labels = np.unique(song_labels)
int_to_label = {i: label for i, label in enumerate(unique_labels)}
label_to_int = {label: i for i, label in enumerate(unique_labels)}

##Encode labels
encoded_labels = np.array([label_to_int[label] for label in song_labels])

##Turn to tensor
labels = torch.tensor(encoded_labels)

#Combine into tensor dataset
dataset = TensorDataset(input_ids, attention_masks, labels)

#Split data into training, validation, test (80/10/10)
train_size = int(0.8 * len(dataset))
val_size = int(0.1 * len(dataset))
test_size = len(dataset) - train_size - val_size

train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])
print('{} training samples, {} validation samples, {} test samples'.format(len(train_dataset), len(val_dataset), len(test_dataset))) ##Should be around 5500 (1/10 of ideal)
# Out:
# 2378 training samples, 297 validation samples, 298 test samples

# %%
##Create Dataloaders to save memory during training, so data doesnt have to be loaded to sample
train_dataloader = DataLoader(
    train_dataset,
    sampler = RandomSampler(train_dataset), ##We want to train randomly on data
    batch_size=batch_size
)

validation_dataloader = DataLoader(
    val_dataset,
    sampler = SequentialSampler(val_dataset), ##For Validation, order doesnt matter
    batch_size=batch_size
)

test_dataloader = DataLoader(
    test_dataset,
    sampler = SequentialSampler(test_dataset), ##For Testing, order doesnt matter
    batch_size=batch_size
)

# %%
#Load BertForSequenceClassification (base bert with a linear layer for classification)
model = BertForSequenceClassification.from_pretrained(
    "bert-base-uncased", ##12 Layer Bert Model, uncased Vocab
    num_labels = num_genres,
    output_attentions = False,
    output_hidden_states = False,
)

#setup optimizer
optimizer = AdamW(
    model.parameters(),
    lr = learning_rate, ##Using low learning rate
    eps = 1e-8          ##Prevents divide by 0
)

#calculate steps for training total
total_steps = len(train_dataloader) * epochs

##Use linear schedular to avoid overfitting
scheduler = get_linear_schedule_with_warmup(
    optimizer,
    num_warmup_steps = warmup_steps,
    num_training_steps = total_steps
)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
##Helper Functions for Metrics

def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

def flat_f1(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return f1_score(labels_flat, pred_flat, average='weighted', zero_division=0)

def flat_precision(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return precision_score(labels_flat, pred_flat, average='weighted', zero_division=0)

def flat_recall(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return precision_score(labels_flat, pred_flat, average='weighted', zero_division=0)

def format_time(elapsed):
    elapsed_round = int(round(elapsed))
    return str(datetime.timedelta(seconds=elapsed_round))

# %%
##Evaluate Baseline BERT model

print('Baseline Model')

model.to(device)

print("")
print("Running Validation...")

#set start time for Validation
t0 = time.time()

#Put model in eval mode
model.eval()

#Initalize arrays
base_all_preds = []
base_all_labels = []

base_batch_loss = []
base_batch_accuracy = []
base_batch_f1 = []
base_batch_precision = []
base_batch_recall = []
nb_eval_steps = 0

#Evaluate Batchwise
for batch in validation_dataloader:

  b_input_ids = batch[0].to(device)
  b_input_mask = batch[1].to(device)
  b_labels = batch[2].to(device)

  with torch.no_grad():
    output = model(
      b_input_ids,
      token_type_ids = None,
      attention_mask = b_input_mask,
      labels = b_labels
    )

  loss = output.loss
  logits = output.logits

  logits = logits.detach().cpu().numpy()
  label_ids = b_labels.to('cpu').numpy()


  pred_flat = np.argmax(logits, axis=1).flatten()
  labels_flat = label_ids.flatten()

  base_all_preds.extend(pred_flat)
  base_all_labels.extend(labels_flat)

  base_batch_loss.append(loss.item())
  base_batch_accuracy.append(flat_accuracy(logits, label_ids))
  base_batch_f1.append(flat_f1(logits, label_ids))
  base_batch_precision.append(flat_precision(logits, label_ids))
  base_batch_recall.append(flat_recall(logits, label_ids))

validation_time = format_time(time.time()-t0)
print("Validation took: {:}".format(validation_time))
print("Out Of The Box Accuracy: {0:.2f}".format(np.mean(base_batch_accuracy)))
print("Out Of The Box F1: {0:.2f}".format(np.mean(base_batch_f1)))
print("Out Of The Box Precision: {0:.2f}".format(np.mean(base_batch_precision)))
print("Out Of The Box Loss: {0:.2f}".format(np.mean(base_batch_loss)))
print("Out Of The Box Recall: {0:.2f}".format(np.mean(base_batch_recall)))
print("")
##Create Confusion matrix for pre-finetuning
base_labels_decode =np.array([int_to_label[i] for i in base_all_labels])
base_preds_decode = np.array([int_to_label[i] for i in base_all_preds])

unique_labels_base= np.unique(base_labels_decode)

cm = confusion_matrix(base_labels_decode, base_preds_decode, labels=unique_labels_base)
print("Pre Finetuning Confusion Matrix:")
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=unique_labels_base, yticklabels=unique_labels_base)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Pre-Finetuning Confusion Matrix')
plt.tight_layout()

base_dir = '/content/CSCI3832_FinalProject/SupplementaryMaterials/'
# Create folder name with today's date
today_str = datetime.date.today().strftime('%Y-%m-%d')
subfolder_name = f"{today_str}_training"
save_directory = os.path.join(base_dir, subfolder_name)

# Create the directory if it doesn't exist
os.makedirs(save_directory, exist_ok=True)

# Save the plot as a JPG image to the specified path
plt.savefig(os.path.join(save_directory, 'pre-finetune-confusion-matrix.jpg'))
plt.show()
# Out:
# Baseline Model
#
# Running Validation...
# Validation took: 0:00:08
# Out Of The Box Accuracy: 0.06
# Out Of The Box F1: 0.03
# Out Of The Box Precision: 0.03
# Out Of The Box Loss: 1.88
#
# Pre Finetuning Confusion Matrix:

# %%
#information on training
training_stats = []

#start time for training
total_t0 = time.time()

#training loop
for epoch_i in range(0, epochs):
    print("")
    print('========== Epoch {:} / {:} =========='.format(epoch_i+1, epochs))
    print('Training...')

    #set start time for this epoch
    t0 = time.time()

    #reset training loss
    total_train_loss = 0

    #put model into training mode
    model.train()

    model.to(device)

    #loop over batches
    for step, batch in enumerate(train_dataloader):

        #report on progress
        if step % 40 == 0 and not step == 0:
            elapsed = format_time(time.time()-t0)

            print('Batch {:>5,} of {:>5,}. Elapsed: {:}.'.format(step, len(train_dataloader), elapsed))

        #unpack training batch from dataloader
        b_input_ids = batch[0].to(device)
        b_input_mask = batch[1].to(device)
        b_labels = batch[2].to(device)

        #clear gradients before calculating new ones
        model.zero_grad()



        #do forward pass, return loss and logits
        output = model(
            b_input_ids,
            token_type_ids = None,
            attention_mask = b_input_mask,
            labels=b_labels
        )


        loss = output.loss
        logits = output.logits

        #accumulate training loss
        total_train_loss += loss.item()

        #do backward pass to get gradients
        loss.backward()

        ##Clip gradients to fix exploding gradient problem
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        #update parameters and take a step using new gradients
        optimizer.step()

        #update the learning rate
        scheduler.step()

    avg_train_loss = total_train_loss / len(train_dataloader)

    training_time = format_time(time.time()-t0)

    print("")
    print("Average Training Loss: {0:.2f}".format(avg_train_loss))
    print("Training Epoch took : {:}".format(training_time))

    print("")
    print("Running Validation...")

    t0 = time.time()

    model.eval()

    total_eval_loss = 0
    nb_eval_steps = 0

    batch_loss = []
    batch_accuracy = []
    batch_f1 = []
    batch_precision = []
    batch_recall = []

    all_preds = []
    all_labels = []

    for batch in validation_dataloader:

        b_input_ids = batch[0].to(device)
        b_input_mask = batch[1].to(device)
        b_labels = batch[2].to(device)

        with torch.no_grad():
            output = model(
                b_input_ids,
                token_type_ids = None,
                attention_mask = b_input_mask,
                labels = b_labels
            )

        loss = output.loss
        logits = output.logits

        logits = logits.detach().cpu().numpy()
        label_ids = b_labels.to('cpu').numpy()

        pred_flat = np.argmax(logits, axis=1).flatten()
        labels_flat = label_ids.flatten()

        all_preds.extend(pred_flat)
        all_labels.extend(labels_flat)

        batch_loss.append(loss.item())
        batch_accuracy.append(flat_accuracy(logits, label_ids))
        batch_f1.append(flat_f1(logits, label_ids))
        batch_precision.append(flat_precision(logits, label_ids))
        batch_recall.append(flat_recall(logits, label_ids))

    avg_val_accuracy = np.mean(batch_accuracy)
    avg_val_precision = np.mean(batch_precision)
    avg_val_recall = np.mean(batch_recall)
    avg_val_f1 = np.mean(batch_f1)
    avg_val_loss = np.mean(batch_loss)
    validation_time = format_time(time.time()-t0)

    print(" Validation Accuracy: {0:.2f}".format(avg_val_accuracy))
    print(" Validation Precision: {0:.2f}".format(avg_val_precision))
    print(" Validation Recall: {0:.2f}".format(avg_val_recall))
    print(" Validation F1: {0:.2f}".format(avg_val_f1))
    print(" Validation Loss: {0:.2f}".format(avg_val_loss))
    print(" Validation took: {:}".format(validation_time))

    training_stats.append(
        {
            'epoch': epoch_i + 1,
            'Training Loss': avg_train_loss,
            'Valid. Loss': avg_val_loss,
            'Valid. Accur.': avg_val_accuracy,
            'Valid. Precision': avg_val_precision,
            'Valid. Recall': avg_val_recall,
            'Valid. F1': avg_val_f1,
            'Training Time': training_time,
            'Valid. Time': validation_time,
            'Pred Labels': all_preds,
            'True Labels': all_labels
        }
    )

print("")
print("Training Complete!")
print("Total training took {:} (h:mm:ss)".format(format_time(time.time()-total_t0)))
print("")

pd.set_option('display.precision', 2)

df_stats = pd.DataFrame(data=training_stats)
df_stats = df_stats.set_index('epoch')

base_dir = '/content/CSCI3832_FinalProject/SupplementaryMaterials/'

# Create folder name with today's date
today_str = datetime.date.today().strftime('%Y-%m-%d')
subfolder_name = f"{today_str}_training"
save_directory = os.path.join(base_dir, subfolder_name)

# Create the directory if it doesn't exist
os.makedirs(save_directory, exist_ok=True)

# Save the files into the new subfolder
df_stats.to_csv(os.path.join(save_directory, 'training_eval_data.csv'), index=False)
model.save_pretrained(os.path.join(save_directory, 'trained_bert'))

base_labels_decode =np.array([int_to_label[i] for i in df_stats.iloc[epochs-1, 9]])
base_preds_decode = np.array([int_to_label[i] for i in df_stats.iloc[epochs-1, 8]])

unique_labels_base= np.unique(base_labels_decode)

cm = confusion_matrix(base_labels_decode, base_preds_decode, labels=unique_labels_base)
print("Post Training Finetuning Confusion Matrix:")
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=unique_labels_base, yticklabels=unique_labels_base)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Post Finetuning Confusion Matrix')
plt.tight_layout()


# Save the plot as a JPG image to the specified path
plt.savefig(os.path.join(save_directory, 'post-finetune-confusion matrix.jpg'))
print(f"Files saved to: {save_directory}")
plt.show()
# Out:
# ========== Epoch 1 / 5 ==========
# Training...
# Batch    40 of    75. Elapsed: 0:01:51.
#
# Average Training Loss: 1.67
# Training Epoch took : 0:03:29
#
# Running Validation...
#  Validation Accuracy: 0.37
#  Validation Precision: 0.30
#  Validation Recall: 0.30
#  Validation F1: 0.30
#  Validation Loss: 1.54
#  Validation took: 0:00:09
#
# ========== Epoch 2 / 5 ==========
# Training...
# Batch    40 of    75. Elapsed: 0:01:51.
#
# Average Training Loss: 1.42
# Training Epoch took : 0:03:28
#
# Running Validation...
#  Validation Accuracy: 0.41
#  Validation Precision: 0.44
#  Validation Recall: 0.44
#  Validation F1: 0.38
#  Validation Loss: 1.44
#  Validation took: 0:00:09
#
# ========== Epoch 3 / 5 ==========
# Training...
# Batch    40 of    75. Elapsed: 0:01:51.
#
# Average Training Loss: 1.23
# Training Epoch took : 0:03:29
#
# Running Validation...
#  Validation Accuracy: 0.43
#  Validation Precision: 0.42
#  Validation Recall: 0.42
#  Validation F1: 0.39
#  Validation Loss: 1.38
#  Validation took: 0:00:09
#
# ========== Epoch 4 / 5 ==========
# Training...
# Batch    40 of    75. Elapsed: 0:01:51.
#
# Average Training Loss: 1.08
# Training Epoch took : 0:03:28
#
# Running Validation...
#  Validation Accuracy: 0.49
#  Validation Precision: 0.54
#  Validation Recall: 0.54
#  Validation F1: 0.47
#  Validation Loss: 1.32
#  Validation took: 0:00:09
#
# ========== Epoch 5 / 5 ==========
# Training...
# Batch    40 of    75. Elapsed: 0:01:51.
#
# Average Training Loss: 0.97
# Training Epoch took : 0:03:28
#
# Running Validation...
#  Validation Accuracy: 0.49
#  Validation Precision: 0.54
#  Validation Recall: 0.54
#  Validation F1: 0.48
#  Validation Loss: 1.29
#  Validation took: 0:00:09
#
# Training Complete!
# Total training took 0:18:07 (h:mm:ss)
#
# Post Training Finetuning Confusion Matrix:
# Files saved to: /content/CSCI3832_FinalProject/SupplementaryMaterials/2025-05-06_training

# %%
##Test Trained BERT model

print('TESTING Model')

model.to(device)

print("")
print("Running Testing...")

#set start time for Validation
t0 = time.time()

#Put model in eval mode
model.eval()

#Initalize arrays
test_all_preds = []
test_all_labels = []

test_batch_loss = []
test_batch_accuracy = []
test_batch_f1 = []
test_batch_precision = []
test_batch_recall = []
nb_eval_steps = 0

#Evaluate Batchwise
for batch in test_dataloader:

  t_input_ids = batch[0].to(device)
  t_input_mask = batch[1].to(device)
  t_labels = batch[2].to(device)

  with torch.no_grad():
    output = model(
      t_input_ids,
      token_type_ids = None,
      attention_mask = t_input_mask,
      labels = t_labels
    )

  loss = output.loss
  logits = output.logits

  logits = logits.detach().cpu().numpy()
  label_ids = t_labels.to('cpu').numpy()


  pred_flat = np.argmax(logits, axis=1).flatten()
  labels_flat = label_ids.flatten()

  test_all_preds.extend(pred_flat)
  test_all_labels.extend(labels_flat)

  test_batch_loss.append(loss.item())
  test_batch_accuracy.append(flat_accuracy(logits, label_ids))
  test_batch_f1.append(flat_f1(logits, label_ids))
  test_batch_precision.append(flat_precision(logits, label_ids))
  test_batch_recall.append(flat_recall(logits, label_ids))

testing_time = format_time(time.time()-t0)
print("Testing took: {:}".format(testing_time))
print("Mean Test Accuracy: {0:.2f}".format(np.mean(test_batch_accuracy)))
print("Mean Test F1: {0:.2f}".format(np.mean(test_batch_f1)))
print("Mean Test Precision: {0:.2f}".format(np.mean(test_batch_precision)))
print("Mean Test Loss: {0:.2f}".format(np.mean(test_batch_loss)))
print("Mean Test Recall: {0:.2f}".format(np.mean(test_batch_recall)))
# Create the DataFrame
metrics_df = pd.DataFrame({
    'Loss': test_batch_loss,
    'Accuracy': test_batch_accuracy,
    'F1 Score': test_batch_f1,
    'Precision': test_batch_precision,
    'Recall': test_batch_recall
})

mean_row = metrics_df.mean(numeric_only=True)
mean_row.name = 'Mean'  # Label the new row

# Append using pd.concat (preferred in newer pandas versions)
metrics_df = pd.concat([metrics_df, pd.DataFrame([mean_row])])

metrics_df.to_csv(os.path.join(save_directory, 'test_data.csv'), index=False)

print(metrics_df)
# Out:
# TESTING Model
#
# Running Testing...
# Testing took: 0:00:08
# Mean Test Accuracy: 0.49
# Mean Test F1: 0.48
# Mean Test Precision: 0.53
# Mean Test Loss: 1.24
#       Loss  Accuracy  F1 Score  Precision  Recall
# 0     1.20      0.59      0.59       0.67    0.67
# 1     1.00      0.66      0.63       0.62    0.62
# 2     1.21      0.53      0.49       0.50    0.50
# 3     1.44      0.47      0.47       0.48    0.48
# 4     1.14      0.50      0.51       0.59    0.59
# 5     1.44      0.31      0.30       0.31    0.31
# 6     1.26      0.53      0.51       0.53    0.53
# 7     1.11      0.59      0.56       0.61    0.61
# 8     1.33      0.44      0.41       0.49    0.49
# 9     1.25      0.30      0.33       0.46    0.46
# Mean  1.24      0.49      0.48       0.53    0.53

# %% [markdown]
# We Tried using the gathered test data, but it's distribution is irregular and it had to be pre-processed differently (playlists weren't genre coded). After seeing this, we decided to go to a simple 80/10/10 distribution of training, validation, test. This data isn't used, but the code is left here as a relic of our exploration and process.

# %% [markdown]
# BELOW THIS LINE IS OPTIONAL PLOTS

# %%
df = pd.read_csv('/content/CSCI3832_FinalProject/SupplementaryMaterials/bert_data_top10_version.csv')


x = df['Max Unknown Words']
genre_cols = [col for col in df.columns if col not in ['Max Unknown Words', 'Dataset Length']]
y_raw = [df[genre] for genre in genre_cols]
y_log = [np.log1p(df[genre]) for genre in genre_cols]

fig, axs = plt.subplots(2, 2, figsize=(18, 10), sharex=True)

# --- Top-Left: Regular Line Plot (Raw) ---
for genre in genre_cols:
    axs[0, 0].plot(x, df[genre], label=genre, marker='o')
axs[0, 0].set_title('Raw Genre Counts (Line Plot)')
axs[0, 0].set_ylabel('Genre Count')
axs[0, 0].legend(fontsize='x-small', loc='upper left')
axs[0, 0].grid(True)

# --- Top-Right: Regular Line Plot (Log) ---
for genre in genre_cols:
    axs[0, 1].plot(x, np.log1p(df[genre]), label=genre, marker='o')
axs[0, 1].set_title('Log(Genre Count + 1) (Line Plot)')
axs[0, 1].set_ylabel('Log Adjusted Count')
axs[0, 1].legend(fontsize='x-small', loc='upper left')
axs[0, 1].grid(True)

# --- Bottom-Left: Stacked Area Plot (Raw) ---
axs[1, 0].stackplot(x, y_raw, labels=genre_cols)
axs[1, 0].set_title('Raw Genre Counts (Stacked)')
axs[1, 0].set_xlabel('Max Unknown Words')
axs[1, 0].set_ylabel('Total Genre Count')
axs[1, 0].legend(fontsize='x-small', loc='upper left')
axs[1, 0].grid(True)

# --- Bottom-Right: Stacked Area Plot (Log) ---
axs[1, 1].stackplot(x, y_log, labels=genre_cols)
axs[1, 1].set_title('Log(Genre Count + 1) (Stacked)')
axs[1, 1].set_xlabel('Max Unknown Words')
axs[1, 1].set_ylabel('Total (Log Adjusted)')
axs[1, 1].legend(fontsize='x-small', loc='upper left')
axs[1, 1].grid(True)

plt.tight_layout()

# Save the plot as a JPG image to the specified path
destination_folder = "/content/CSCI3832_FinalProject/SupplementaryMaterials/"  # Replace with the actual path
file_name = "genres_vs_unknowns_top10.jpg"
destination_path = os.path.join(destination_folder, file_name)

# Save the plot as a JPG image to the specified path
plt.savefig(destination_path)
plt.show()

# %%
df = pd.read_csv('/content/CSCI3832_FinalProject/SupplementaryMaterials/bert_data_sorted_full_version.csv')

x = df['Max Unknown Words']
genre_cols = [col for col in df.columns if col not in ['Max Unknown Words', 'Dataset Length']]
y_raw = [df[genre] for genre in genre_cols]
y_log = [np.log1p(df[genre]) for genre in genre_cols]

fig, axs = plt.subplots(2, 2, figsize=(18, 10), sharex=True)

# --- Top-Left: Regular Line Plot (Raw) ---
for genre in genre_cols:
    axs[0, 0].plot(x, df[genre], label=genre, marker='o')
axs[0, 0].set_title('Raw Genre Counts (Line Plot)')
axs[0, 0].set_ylabel('Genre Count')
axs[0, 0].legend(fontsize='x-small', loc='upper left')
axs[0, 0].grid(True)

# --- Top-Right: Regular Line Plot (Log) ---
for genre in genre_cols:
    axs[0, 1].plot(x, np.log1p(df[genre]), label=genre, marker='o')
axs[0, 1].set_title('Log(Genre Count + 1) (Line Plot)')
axs[0, 1].set_ylabel('Log Adjusted Count')
axs[0, 1].legend(fontsize='x-small', loc='upper left')
axs[0, 1].grid(True)

# --- Bottom-Left: Stacked Area Plot (Raw) ---
axs[1, 0].stackplot(x, y_raw, labels=genre_cols)
axs[1, 0].set_title('Raw Genre Counts (Stacked)')
axs[1, 0].set_xlabel('Max Unknown Words')
axs[1, 0].set_ylabel('Total Genre Count')
axs[1, 0].legend(fontsize='x-small', loc='upper left')
axs[1, 0].grid(True)

# --- Bottom-Right: Stacked Area Plot (Log) ---
axs[1, 1].stackplot(x, y_log, labels=genre_cols)
axs[1, 1].set_title('Log(Genre Count + 1) (Stacked)')
axs[1, 1].set_xlabel('Max Unknown Words')
axs[1, 1].set_ylabel('Total (Log Adjusted)')
axs[1, 1].legend(fontsize='x-small', loc='upper left')
axs[1, 1].grid(True)

plt.tight_layout()

# Save the plot as a JPG image to the specified path
destination_folder = "/content/CSCI3832_FinalProject/SupplementaryMaterials/"  # Replace with the actual path
file_name = "genres_vs_unknowns_full.jpg"
destination_path = os.path.join(destination_folder, file_name)

# Save the plot as a JPG image to the specified path
plt.savefig(destination_path)
plt.show()
